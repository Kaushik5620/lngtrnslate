# %%
pip install translate
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\libretranslatepy\\api.py'
# Consider using the `--user` option or check the permissions.
# ...
#                                               0.0/3.8 MB ? eta -:--:--
#                                               0.0/3.8 MB 1.3 MB/s eta 0:00:03
#                                               0.1/3.8 MB 812.7 kB/s eta 0:00:05
#                                               0.1/3.8 MB 655.4 kB/s eta 0:00:06
#      -                                        0.2/3.8 MB 893.0 kB/s eta 0:00:05
#      --                                       0.2/3.8 MB 903.5 kB/s eta 0:00:04
#      --                                       0.2/3.8 MB 885.4 kB/s eta 0:00:04
#      ---                                      0.3/3.8 MB 916.0 kB/s eta 0:00:04
# ...

# %%
import translate
t=translate.Translator(from_lang="en-in",to_lang="bn")
print(t.translate("Need Project login integrated for payroll correction, not sure if best to do this for project login correction page or to integrate in timesheet correction.  Initially I think it would be best to integrate with timesheet correction because we have process in place there and payroll must be recalculated and misc pay inserted and project login must be related to clock in else it can't exist"))
# Out:
# প্রকল্প লগইন প্রয়োজন payroll সংশোধন জন্য ইন্টিগ্রেটেড, যদি প্রকল্প লগইন সংশোধন পৃষ্ঠার জন্য এই ভাল করতে বা বার্থশীট সংশোধন মধ্যে সংহত নিশ্চিত না । প্রাথমিকভাবে আমি মনে করি বার্থশীট সংশোধন সঙ্গে সংহত করা ভাল হবে কারণ আমরা সেখানে প্রক্রিয়া আছে এবং payroll recalculated এবং misc বেতন ঢোকানো এবং প্রকল্প লগইন অন্যথায় এটি বিদ্যমান হতে পারে না ঘড়ি সম্পর্কিত হতে হবে
